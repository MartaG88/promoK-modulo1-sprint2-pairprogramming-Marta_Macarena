# %%
import datetime

class Empleados:
    


    def __init__(self, nombre, apellido, edad, posicion, año, vacaciones, herramientas): #Metodo constructor
        
        self.nombre = nombre
        self.apellido = apellido
        self.edad =  edad
        self.posicion = posicion
        self.año = año
        self.vacaciones = vacaciones
        self.herramientas = herramientas
         
   
    def  descripcion(self):
        
        print(f"el nombre nombre del empleados es {self.nombre}, la posicion es {self.posicion}, el año de ingreso es {self.año}, las vacaciones a disfrutar {self.vacaciones}")


    def cambiando_posicion(self):

        if "excel" and "python" in self.herramientas :
            print("genial tienes las heramientas necesarias")

        elif "python" not in self.herramientas:
            print("No estas contratado")

        else:
            print("tienes python, lo podemos valorar")
             
           
    def  calcular_antiguedad(self):

        
        

    
        
    
    
    
    
    
          
    def solicitar_aumento_vacaciones():
        pass
    def  registrar_herramienta():
        pass
    def   cambiar_posicion():
        pass
    def   tomar_vacaciones():
        pass
    def   solicitar_aumento_salario():
        pass
    def    realizar_evaluacion ():
        pass
